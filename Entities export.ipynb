# %% [markdown]
# At this stage, we are working with json-files that were obtained at the output of I. Karpov's algorithm for extracting entities from text files. <br> <br>
# Due to the too large files size, further work's continued only with this year's news from the RBC channel.

# %%
import pandas as pd
import json

# %%
f1 = open('/Users/.../Downloads/data10000.json')
data1 = json.load(f1)

f2 = open('/Users/.../Downloads/data20000.json')
data2 = json.load(f2)

f3 = open('/Users/.../Downloads/data30000.json')
data3 = json.load(f3)

f4 = open('/Users/.../Downloads/data40000.json')
data4 = json.load(f4)

f5 = open('/Users/.../Downloads/data50000.json')
data5 = json.load(f5)

f6 = open('/Users/.../Downloads/data60000.json')
data6 = json.load(f6)

f7 = open('/Users/.../Downloads/data70000.json')
data7 = json.load(f7)

f8 = open('/Users/.../Downloads/data80000.json')
data8 = json.load(f8)

f9 = open('/Users/.../Downloads/data90000.json')
data9 = json.load(f9)

f10 = open('/Users/.../Downloads/data100000.json')
data10 = json.load(f10)

f11 = open('/Users/.../Downloads/data110000.json')
data11 = json.load(f11)

f12 = open('/Users/.../Downloads/data120000.json')
data12 = json.load(f12)

f13 = open('/Users/.../Downloads/data130000.json')
data13 = json.load(f13)

f14 = open('/Users/.../Downloads/data140000.json')
data14 = json.load(f14)

f15 = open('/Users/.../Downloads/data150000.json')
data15 = json.load(f15)

f16 = open('/Users/.../Downloads/data160000.json')
data16 = json.load(f16)

f17 = open('/Users/.../Downloads/data170000.json')
data17 = json.load(f17)

f18 = open('/Users/.../Downloads/data180000.json')
data18 = json.load(f18)

f19 = open('/Users/.../Downloads/data190000.json')
data19 = json.load(f19)

f20 = open('/Users/.../Downloads/data200000.json')
data20 = json.load(f20)

# %%
persons = []

# %%
for i in range(len(data20)): # смотрим новость x20
    lst = []
    for j in range(len(data[i]['objects'])): # смотрим объекты в новости
        if data[i]['objects'][j]['type'] == 'персона': # если персона
            for k in range(len(data[i]['objects'][j]['properties'])):
                if data[i]['objects'][j]['properties'][k]['name']=='Lastname':
                    lst.append(data[i]['objects'][j]['properties'][k]['value']) # то добавляем в список персону
    if len(lst) > 0:
        persons.append(lst)

# %%
persons_pairs = [i for i in persons if len(i)>1]

# %%
persons_pairs
# Out:
# [['ПРОНИЧЕВА', 'ШИГАПОВ', 'СЕРГИЕВА', 'ТРЕГУЛОВА', 'РАДОНЕЖСКИЙ'],
#  ['СУПЕР', 'Орешкин', 'КУЗАХМЕТОВ'],
#  ['ПРИЛЕПИН', 'Никитин'],
#  ['МАСЛОВ', 'МАСЛОВА'],
#  ['МОРДАШОВ', 'Мишустин'],
#  ['БЛИНКЕН', 'Байден'],
#  ['БЕРНС', 'Байден', 'ПЕЛОСИ', 'ХЕНЛЕ', 'БЛИНКЕН'],
#  ['ПАШИНЯН', 'Эрдоган'],
#  ['КЛИМАТ', 'АФРИК'],
#  ['УОЛЛЕС', 'Аксенов'],
#  ['Песков', 'ПАШИНЯН'],
#  ['Медведев', 'МЮЛЛЕР', 'ДЖОБС'],
#  ['ГЛАДКОВ', 'МАСЛОВ'],
#  ['МЕНЕНДЕС', 'РИШ'],
#  ['ПАШИНЯН', 'ПАШИНЯН'],
#  ['Матвиенко', 'ШМЕЛЕВ'],
#  ['ПРИГОЖИН', 'УТКИН', 'ВАГНЕР', 'РАЗГРУЗК'],
#  ['Путин', 'ВОРОБЬЕВ'],
#  ['ПРИГОЖИН', 'ДЕЛИМХАНОВ'],
#  ['ТАТАРСКИЙ', 'ПОПКОВ'],
#  ['ЦВЕТКОВА', 'Рязанов', 'ТОДОРОВСКИЙ', 'ХУЦИЕВ', 'ДАНЕЛИЯ'],
#  ['Мишустин', 'Путин'],
#  ['Месси', 'ГАЛЬТЬЕ'],
#  ['Песков', 'Путин'],
#  ['ТЕРЕХОВ', 'СИНЕГУБОВ'],
#  ['ВУЧИЧ', 'Путин'],
#  ['Лукашенко', 'Путин'],
#  ['ГЛАДКОВ', 'Путин'],
#  ['РАМАФОС', 'БРИГЕТИ', 'Путин'],
#  ['Маске', 'АРНО'],
#  ['АФЕВОРКА', 'Путин', 'АФЕВОРКИ'],
#  ['МАКРОН', 'МАКРОН'],
#  ['ВОЙНОВА', 'НОВОЛОДСКАЯ', 'ЕКИМОВ'],
#  ['Дуда', 'Путин'],
#  ['Путин', 'МАКРОН'],
#  ['ХУБЕЗОВ', 'БАШАНКАЕВ'],
#  ['ЗЕЛЕНСКИЙ', 'МАКРОН'],
#  ['Путин', 'АФЕВОРКА'],
#  ['КИРБИ', 'Путин'],
#  ['КРОУ', 'ЦИММЕР'],
#  ['Пачино', 'АЛЬФАЛЛА', "Д'АНДЖЕЛО"],
#  ['КАРТАПОЛОВ', 'КРАСОВ'],
#  ['Песков', 'Кадыров'],
#  ['Песков', 'Путин', 'Эрдоган'],
#  ['ЗУБАРЕВ', 'ШВЫТКИН'],
#  ['ЯКУБОВСКИЙ', 'Бастрыкин', 'Клишас'],
#  ['КАРЕВА', 'КОРСАК'],
#  ['Эрдоган', 'Путин', 'ЗЕЛЕНСКИЙ', 'ХАНДЕ'],
#  ['Медведев', 'КЛЕВЕРЛИ'],
#  ['КОЛЕСНИК', 'ЛОКОТА', 'ГРИЩЕНКО'],
#  ['БУРМИСТРОВ', 'МУСАТОВ'],
#  ['Титов', 'Путин'],
#  ['КАЛИНИН', 'РУБЛЕВ', 'Христос'],
#  ['КЛЕВЕРЛИ', 'Путин'],
#  ['БЛИНКЕН', 'КРИСТЕРССОН'],
#  ['Эрдоган', 'Кылычдароглу'],
#  ['ШОР', 'САНДУ', 'Санду'],
#  ['ПРОМЕС', 'МАЛЕВИЧ'],
#  ['ШОР', 'ТАУБЕР', 'КАВКАЛЮК', 'ПЛАХОТНЮК', 'ЧАЙКА'],
#  ['САВЕСКУЛ',
#   'КРАВЧЕНКО',
#   'БОГАЧЕНКО',
#   'БАБЕШКО',
#   'КОЛМАЧЕВ',
#   'МЕЛЬНИКОВ',
#   'ЕЛИСЕЕВ',
#   'МЕДВЕДЕВ',
#   'БАЛАХИН'],
#  ['СЫРСКИЙ', 'ЗАЛУЖНЫЙ'],
#  ['ЗЕЛЕНСКИЙ', 'ПУТИНА', 'Песков'],
#  ['Маске', 'ГАН'],
#  ['Песков', 'Путин'],
#  ['Песков', 'Путин'],
#  ['БЕРКОВИЧ', 'ПЕТРИЙЧУК'],
#  ['КОРНЕВ', 'ФЕДУТИНОВ', 'РОГОЗИН'],
#  ['Шредер', 'ЭСКЕН'],
#  ['Джокович', 'ГАРРОС'],
#  ['ЗЕЛЕНСКИЙ', 'Эрдоган'],
#  ['КУРТИ', 'ВУЧИЧ'],
#  ['Мадуро', 'ЛУЛА'],
#  ['Путин', 'Эрдоган'],
#  ['БОРРЕЛЬ', 'БОРРЕЛЬ'],
#  ['ГРЭМ', 'ЗЕЛЕНСКИЙ', 'Бастрыкин'],
#  ['АРБЕНИНА', 'РЕРИХ'],
#  ['СКОРСЕЗЕ', 'Христос', 'ДЕФО', 'ВОЛОКОЛАМСКИЙ'],
#  ['Лукашенко', 'Набиулина'],
#  ['РАЙКИН', 'ЛОМКИН'],
#  ['Путин', 'Мантуров'],
#  ['ШВЕТСКИЙ', 'ВАЛИЕВА'],
#  ['Канделаки', 'Бровко', 'МАЛУШЕНКО', 'МОСКВИН', 'СЛОБОДЕНЮК'],
#  ['Захарова', 'ГРЭМ'],
#  ['ТОКАЕВ', 'Лукашенко'],
#  ['Лукашенко', 'Путин', 'Набиулина'],
#  ['Ривз', 'МЕЙЛХАУЗ'],
#  ['ГРЭМ', 'Бастрыкин'],
#  ['МЕЛЬНИЧЕНКО', 'БЫРИХИН'],
#  ['Байден', 'МАККАРТИ'],
#  ['ФИЛЕВ', 'КУДЕЛЬКИН', 'ФИЛЕВА', 'ПОМЕРАНЦЕВ'],
#  ['ГРЭМ', 'ЗЕЛЕНСКИЙ'],
#  ['ЭРДОГАН', 'КЫЛЫЧДАРОГЛУ'],
#  ['Эрдоган', 'Кылычдароглу'],
#  ['ЭРДОГАН', 'КЫЛЫЧДАРОГЛУ'],
#  ['Кылычдароглу', 'ЭРДОГАН'],
#  ['ЭРДОГАН', 'КЫЛЫЧДАРОГЛУ'],
#  ['Эрдоган', 'Кылычдароглу'],
#  ['ПУГАЧЕВА', 'Макаревич'],
#  ['Лукашенко', 'ТОКАЕВ'],
#  ['Эрдоган', 'Кылычдароглу'],
#  ['Путин', 'ГАГАРИН'],
#  ['ПОДОЛЯК', 'ГАЛУЗИН'],
#  ['КАЛИНИН', 'РУБЛЕВ'],
#  ['Кавусоглу', 'КЫЛЫЧДАРОГЛУ'],
#  ['Эрдоган', 'Кылычдароглу'],
#  ['КИССИНДЖЕР', 'Байден'],
#  ['Трамп', 'ДЖОНСОН'],
#  ['ГАДЖИЕВ',
#   'ИНОЗЕМЦЕВ',
#   'АЛЛЕМАН',
#   'АРХИПОВА',
#   'ГАБУЕВ',
#   'КАРНЕГИ',
#   'ЦУКАНОВА'],
#  ['БИ-2', 'БОРТНИК'],
#  ['ПОДОЛЯК', 'ХУЭЙ'],
#  ['СЕРЕБРЕННИКОВ', 'КАБАНОВ'],
#  ['КРАВЧЕНКО', 'КНЯЗЕВ'],
#  ['Песков', 'РУБЛЕВ'],
#  ['ДРОЖЖИНА', 'БАТАЛОВ', 'ЛЕОНТЕНКО', 'ЦИВИН', 'БАТАЛОВ'],
#  ['ДЕСАНТИС', 'Трамп'],
#  ['ЗЕЛЕНСКИЙ', 'Медведев'],
#  ['Джордан', 'МЭЛОУН'],
#  ['КОЖУХОВА', 'Новак', 'КАРПУНИН', 'Юдаева', 'ДАНИЛОВА'],
#  ['Новиков', 'ТЕПЛИНСКИЙ', 'Каракаев', 'ПАРШИН', 'ЗУСЬКО'],
#  ['ЭЛЛЕНДЕР', 'ДЮЖАРРИК'],
#  ['Путин', 'ПАШИНЯН', 'Алиев'],
#  ['ПАШИНЯН', 'ЖАПАРОВ', 'ТОКАЕВ', 'Лукашенко', 'Путин', 'Алиев'],
#  ['СИЛАНТЬЕВ', 'Бастрыкин', 'БЕРКОВИЧ', 'ПЕТРИЙЧУК'],
#  ['УФИМЦЕВ', 'АФАНАСЬЕВ', 'БЕЛЯКОВ'],
#  ['Немцов', 'Касьянов'],
#  ['Песков', 'Путин'],
#  ['Шойгу', 'ХРЕНИН'],
#  ['ГРАЙНЕР', 'Бут'],
#  ['ПАПИКЯН', 'ЛУЙО'],
#  ['Шойгу', 'ХРЕНИН'],
#  ['БЕЛОУСОВ', 'ЛИСОВ'],
#  ['Абрамович', 'БОЛИ'],
#  ['КУРКОВИЧ', 'БОГОМАЗ'],
#  ['ЭРДОГАН', 'Кылычдароглу', 'Путин'],
#  ['Алиев', 'ПАШИНЯН'],
#  ['БОУИ', 'Тернер'],
#  ['ДЕСАНТИС', 'Маске'],
#  ['КАЗАКОВА', 'ИСАЕВ'],
#  ['ПАШИНЯН', 'ДАВОЯН', 'Захарова'],
#  ['Лукашенко', 'Путин', 'Кучма'],
#  ['ТОРКУНОВ', 'ПЛАХОТНЮК'],
#  ['Баринов', 'Путин', 'ДЕМЕТЕР'],
#  ['Путин', 'ГАЛУЗИН'],
#  ['Набиулина', 'ФАРЗИН'],
#  ['Песков', 'ГЛАДКОВ'],
#  ['ПРИГОЖИН', 'ДОЛГОВ'],
#  ['УОЛЛЕС', 'РЕЗНИКОВ'],
#  ['Мишустин', 'Си', 'Путин'],
#  ['ДОДИК', 'Путин'],
#  ['Аксенов', 'ЗЕЛЕНСКИЙ', 'БУРЯК'],
#  ['КИСИД', 'ХАЯСИ'],
#  ['ДЕСАНТИС', 'Маске', 'Трамп'],
#  ['ДОРОХОВ', 'Христос'],
#  ['ДЕСАНТИС', 'Маске'],
#  ['САФРОНОВ', 'КАТЧЕВ'],
#  ['РОШЕ', 'СОБОЛЕВ', 'ГЕТАДАРЯН'],
#  ['Путин', 'ЗОРЬКИН'],
#  ['Путин', 'ЗОРЬКИН', 'ПОСПОЛИТА'],
#  ['ОСТРОВСКИЙ', 'ЗВЕРЬ'],
#  ['Песков', 'Путин'],
#  ['ЧБД', 'МОРОЗОВЫ'],
#  ['Медведев', 'СИСУЛИТ'],
#  ['Путин', 'ТРАВНИКОВ'],
#  ['ДЮЖАРРИК', 'СТАНО'],
#  ['КУРКОВИЧ', 'БОГОМАЗ'],
#  ['СВИСТУЛА', 'РЕДЬКИН', 'ЕВТУШОК', 'Ткачев'],
#  ['ЛЕВКИН', 'ДЮКОВ'],
#  ['Песков', 'Путин'],
#  ['ШМЫГАЛЬ', 'ФЕДОРОВ'],
#  ['ПРОТАСЕВИЧ', 'ПУТИЛО', 'САПЕГА', 'Лукашенко'],
#  ['Путин', 'БУТИН'],
#  ['Дерипаска', 'НИКИТИН'],
#  ['Лукашенко', 'Путин'],
#  ['ЧЕКАЛИНА', 'ТРЕТЬЯКОВ'],
#  ['КЛИМОВСКИЙ', 'БОГОМАЗ'],
#  ['Кудрин', 'Путин', 'Потанин', 'МОРДАШОВ', 'Аликперов', 'МАККАРТИ', 'Байден'],
#  ['ГЕЙТС', 'ЭПШТЕЙН'],
#  ['КИСИД', 'ЗЕЛЕНСКИЙ'],
#  ['ИНАСИУ', 'ЗЕЛЕНСКИЙ', 'МАКРОН'],
#  ['МЕДВЕДЕВ', 'РУНЕ'],
#  ['СОБОЛЕВ', 'ЗАБОЛОТНЫЙ', 'РОША'],
#  ['Ходорковский', 'АРНО', 'БУДАЕВ'],
#  ['ХАН', 'АЙТАЛ', 'Путин'],
#  ['Байден', 'Путин'],
#  ['Бастрыкин', 'ЖУРАВЕЛЬ'],
#  ['ЗУРАБИШВИЛИ', 'ГАИАШВИЛИ'],
#  ['КАЛИНИН', 'ЧЕРНЕГА'],
#  ['РУБЛЕВ', 'ЛИФШИЦ', 'ЛОШАК'],
#  ['ЗЕЛЕНСКИЙ', 'НИКИФОРОВ', 'ЗЕЛЕНСКИЙ'],
#  ['Байден', 'ЗЕЛЕНСКИЙ'],
#  ['Медведев', 'Маске'],
#  ['ЗВАРЫЧ', 'ЯСИНА', 'ЗЕЛЕНСКИЙ'],
#  ['НАУМОВ', 'СЕРДЮЧКА'],
#  ['БАФФЕТ', 'Сорос', 'БЬЮРРИ'],
#  ['ШЕБЕКИНСКИЙ', 'ГЛАДКОВ'],
#  ['ЖДАНУХИН', 'СЕМЕНОВСКИЙ'],
#  ['СНИГИРЕВА', 'СНЕГИРЕВА'],
#  ['БЕЗОС', 'Маске'],
#  ['ВАШАДЗЕ', 'БЕРАЯ'],
#  ['КИММЕЛ', 'КОЛЬБЕР'],
#  ['ЕРМАК', 'ЗЕЛЕНСКИЙ', 'Байден'],
#  ['ГЕРШКОВИЧ', 'Лавров'],
#  ['Кравцов', 'Сорос'],
#  ['ЛИТВИНЕНКО', 'МИЛЛИОНЩИКОВ', 'КАРГИН'],
#  ['ХАН', 'Путин', 'ЛЬВОВОЙ-БЕЛОВА'],
#  ['КАЛВИ', 'КАШТАНОВА', 'ДЕЛЬПАЛЬ'],
#  ['КАРАЧИНСКИЙ', 'ПУМПЯНСКИЙ'],
#  ['ПИСКАРЕВ', 'АЛЕКСАНДРОВ', 'ОСКОЛКОВ'],
#  ['Путин', 'Эрдоган'],
#  ['ПОТАНИН', 'АЛЕКПЕРОВ'],
#  ['БЛАВАТНИК', 'Вексельберг'],
#  ['Путин', 'Сыромолотов'],
#  ['Потанин', 'Аликперов'],
#  ['Горин', 'ФАРУК'],
#  ['Собянин', 'ТОЛСТОЙ'],
#  ['МИШЕЛЬ', 'СУНАК'],
#  ['ЗЕЛЕНСКИЙ', 'КИСИД'],
#  ['ФАЗЕЛЬ', 'Путин'],
#  ['МЕДВЕДЕВ', 'ЧЕКАНОВ', 'ПРИГОЖИН', 'НУЖИН'],
#  ['ЗУРАБИШВИЛИ', 'КОБАХИДЗЕ', 'ЗУРАБИШВИЛИ'],
#  ['Лавров', 'ОДОНГО'],
#  ['НАДАЛЬ', 'ГАРРОСЕ'],
#  ['Дегтерев', 'Путин'],
#  ['ПАШИНЯН', 'Путин', 'Алиев'],
#  ['Дуров', 'РЕВА'],
#  ['ЛОБАНОВ', 'ПОНОМАРЕВ', 'ОКУШКО', 'ФИЛЬЧЕНКО', 'ХАНАНАШВИЛИ', 'КАЛИНИН'],
#  ['Песков', 'РАМАФОСА', 'Путин'],
#  ['ПУГАЧЕВА',
#   'ЕЛЬЦИНА',
#   'КОЛЯДА',
#   'РОЙЗМАН',
#   'ИДАМЖАПОВ',
#   'ФЕДЕРМЕССЕР',
#   'ГЛИНКА'],
#  ['Си', 'ТОКАЕВ'],
#  ['КИССИНДЖЕР', 'Путин'],
#  ['Силуанов', 'Путин'],
#  ['КАДЕТ', 'КАДЕТ'],
#  ['КОРЕНЕВСКИЙ', 'СТАРОВОЙТ'],
#  ['СИЛАНТЬЕВ', 'БЕРКОВИЧ'],
#  ['СИЛАНТЬЕВ',
#   'БЕРКОВИЧ',
#   'ДЫМАРСКИЙ',
#   'Бастрыкин',
#   'КАРПИНСКАЯ',
#   'ХИЗРИЕВА',
#   'ЗАМЫШЕВСКАЯ'],
#  ['ВЫРЫПАЕВ', 'РОДНЯНСКИЙ'],
#  ['ДЕПП',
#   'АНДЕРСОН',
#   'КАУРИСМЯКА',
#   'КОРЭЭДА',
#   'ХЕЙНС',
#   'ЛОУЧ',
#   'ВЕНДЕРС',
#   'РОРВАХЕР',
#   'СКОРСЕЗЕ',
#   'ДЖОНС',
#   'МЭНГОЛД',
#   'ЛЕВИНСОН',
#   'ДЕПП',
#   'Тесфайе'],
#  ['ЗЕЛЕНСКИЙ', 'ЖОВКВА'],
#  ['БУДУЕВ', 'СЕРЕГИНА'],
#  ['АВДЕЕВ', 'Лукашенко'],
#  ['Чубайс', 'СМИРНОВА'],
#  ['ГУЦУЛ', 'НАЦИОНАЛЬНЫЙ', 'НАЦИОНАЛЬНЫЙ', 'СТАРИНСКИ'],
#  ['РУБЛЕВ', 'Путин'],
#  ['АББАСИ', 'АМИР-ЭБРАХИМИ'],
#  ['РАМАФОС', 'Путин', 'ЗЕЛЕНСКИЙ'],
#  ['РУБЛЕВ', 'Песков', 'Путин'],
#  ['Шредер', 'КИМ-ШРЕДЕР'],
#  ['СОЛТАНОВСКИЙ', 'Путин', 'АВДЕЕВ'],
#  ['Медведев', 'МАКРОН'],
#  ['ЗВЕГИНЦЕВ', 'МАСЛОВ', 'ШИПЛЮК', 'ЗВЕГИНЦЕВА'],
#  ['ТРОФИМОВ', 'Потанин'],
#  ['КНЯЗЕВ', 'ЖЕВАГО'],
#  ['ДАРИЙ', 'ТРАМП'],
#  ['ЭРДОГАН', 'КЫЛЫЧДАРОГЛУ'],
#  ['ХОЦЕНКО', 'КУЧУМОВА'],
#  ['Илюмжинов', 'Ельцин', 'ПУПКИН', 'САИ'],
#  ['БЛИНОВСКАЯ', 'БЛИНОВСКИЙ'],
#  ['ПРИГОЖИН', 'СОБОЛЕВ'],
#  ['ЖЕЛОБОВ', 'ТЮКТЕЕВ', 'ТЮКЕЕВ', 'ТОМЫШЕВ', 'ЦЕЛИКОВ', 'БЕСПАЛОВ'],
#  ['РУБЛЕВ', 'НЕВСКИЙ', 'ПОРХОВСКИЙ', 'Пиатровский'],
#  ['КАРЛОС', 'МАРОЖАН'],
#  ['КОРНЕТ', 'ПАСЕЧНИК'],
#  ['Путин',
#   'РУБЛЕВ',
#   'ГОСТЕПРИИМСТВО',
#   'ГРОЗНЫЙ',
#   'РАДОНЕЖСКИЙ',
#   'НЕРСЕСЯН',
#   'ВИГИЛЯНСКИЙ'],
#  ['БЛИНОВСКАЯ', 'БЛИНОВСКИЙ'],
#  ['СКОРОБОГАТОВ', 'ЧКАЛОВ', 'ЧКАЛОВ'],
#  ['ЭРДОГАН', 'КЫЛЫЧДАРОГЛУ'],
#  ['МАРИНЫЧЕВ', 'Иванов', 'Путин'],
#  ['ЛОКОТЬ', 'СТАРОВОЙТ'],
#  ['Эрдоган', 'Кылычдароглу'],
#  ['РЕМБРАНДТ', 'ПЕТТИФЕР'],
#  ['Эрдоган', 'Кылычдароглу'],
#  ['ЭРДОГАН', 'КЫЛЫЧДАРОГЛУ'],
#  ['ЭРДОГАН', 'КЫЛЫЧДАРОГЛУ'],
#  ['КЫЛЫЧДАРОГЛУ', 'ЭРДОГАН'],
#  ['ЭРДОГАН', 'КЫЛЫЧДАРОГЛУ'],
#  ['ЭРДОГАН', 'КЫЛЫЧДАРОГЛУ'],
#  ['КЫЛЫЧДАРОГЛУ', 'ЭРДОГАН'],
#  ['ЭРДОГАН', 'КЫЛЫЧДАРОГЛУ'],
#  ['ЭРДОГАН', 'КЫЛЫЧДАРОГЛУ'],
#  ['КЫЛЫЧДАРОГЛУ', 'ЭРДОГАН'],
#  ['КЫЛЫЧДАРОГЛУ', 'ЭРДОГАН'],
#  ['КЫЛЫЧДАРОГЛУ', 'ЭРДОГАН'],
#  ['Эрдоган', 'КАЛЫЧДАРОГУ'],
#  ['БЛИНОВСКАЯ', 'Бастрыкин'],
#  ['ЗЕЛЕНСКИЙ', 'ШОЛЬЦ'],
#  ['Лукашенко', 'ГОЛОВЧЕНКО'],
#  ['БРОВКО', 'МАКАРОВ'],
#  ['Кылычдароглу', 'Эрдоган'],
#  ['ЗЕЛЕНСКИЙ', 'Штайнмайер'],
#  ['Бастрыкин', 'МОИСЕЕВ'],
#  ['ЭРДОГАН', 'Кылычдароглу', 'ГОСПОДИН', 'ПУТИН', 'ПУТИН', 'Путин'],
#  ['ЗЕЛЕНСКИЙ', 'АХМЕТОВ'],
#  ['МИРОШНИК', 'МАРОЧКО'],
#  ['Маске', 'ЯККАРИНО'],
#  ['СОКУРОВ', 'БЕРКОВИЧ', 'ПЕТРИЙЧУК'],
#  ['БУРЛ', 'СОЛОМОН', 'Цукерберг', 'АРМСТРОНГ'],
#  ['Эрдоган', 'Кылычдароглу'],
#  ['АБРЕУ', 'БОРЕЛЛИ'],
#  ['КОЛМАКОВ', 'СИЛКИНА'],
#  ['РИЧИ', 'АФФЛЕК'],
#  ['Маттарелла', 'ЗЕЛЕНСКИЙ'],
#  ['Москалькова', 'ФАДЕЕВ'],
#  ['ПУГАЧЕВА', 'ЧУПРАКОВА', 'ЮДАШКИН'],
#  ['ПАНФИЛОВ', 'ВАРШАВЕР'],
#  ['МАТВЕЕВ', 'Путин'],
#  ['МИЛЬЧАКОВА', 'ЛИНЧИК'],
#  ['БЫКОВ', 'ЦВЕТОМУЗЫКА'],
#  ['Маске', 'ЯККАРИНО'],
#  ['РОГОВ', 'ЛЕОНТЬЕВ', 'ПОДДУБНЫЙ', 'КОЦ'],
#  ['КУНИЧИН', 'ЛЯЭНЕМЕТС'],
#  ['ШЕНДЕРОВИЧ', 'ЕЛОВСКИЙ'],
#  ['Кылычдароглу', 'ЭРДОГАН'],
#  ['ЗЕЛЕНСКИЙ', 'МЕЛОНЯ'],
#  ['КОСТОМАРОВ', 'ДОМНИНА'],
#  ['НИКИФОРОВ', 'МОРДАШОВ'],
#  ['ПАНФИЛОВ', 'СКЛИФОСОВСКИЙ', 'ВАРШАВЕР', 'ЧУРИКОВА'],
#  ['СОБОЛЕВ', 'КАРТАПОЛОВ'],
#  ['ЗЕЛЕНСКИЙ', 'АРЕСТОВИЧ'],
#  ['Эрдоган', 'Кылычдароглу'],
#  ['Великая',
#   'ЕГОРЯН',
#   'ПОЗДНЯКОВА',
#   'МАМЕДОВ',
#   'НИКИТИНА',
#   'ИБРАГИМОВ',
#   'РЕШЕТНИКОВ'],
#  ['СЕНАР', 'ПОДЩЕКОЛДИН'],
#  ['ПАШИНЯН', 'АЛИЕВ'],
#  ['Путин', 'Трамп'],
#  ['ГАЛИ', 'ХАСВАН'],
#  ['САНН', 'РЯЙККЕНЕН', 'НИИНИСТ'],
#  ['Шредер', 'КИМ', 'КРЕНЦ', 'ХРУПАЛЛ', 'НЕЧАЕВ'],
#  ['ПОРШЕ', 'ДИТЕР'],
#  ['ПОДОЛЯК', 'БОРРЕЛЬ'],
#  ['Медведев', 'ЩЕЦИН'],
#  ['БЕРКОВИЧ',
#   'РОЗЕНБАУМ',
#   'ЯСНЫЙ',
#   'ПЕТРИЙЧУК',
#   'ГЛАГОЛЕВА',
#   'ЛУНГИН',
#   'РАЙКИН',
#   'ФЕДЕРМЕССЕР',
#   'МЕНЬШИКОВ',
#   'СМЕХОВ'],
#  ['Путин', 'ВОСКРЕСЕНСКИЙ'],
#  ['ГАВРИЛОВ', 'Путин', 'Песков', 'Лавров'],
#  ['Путин', 'Рябков', 'Лавров'],
#  ['КУЧИНСКИС', 'КУЧИНСКИС'],
#  ['ЛЕВЧЕНКО', 'Левченко'],
#  ['Дерипаска', 'ЛОСКУТОВ'],
#  ['ЭРДОГАН', 'КЫЛЫЧДАРОГЛУ'],
#  ['ТАКЕР', 'Маске'],
#  ['БЛИНКЕН', 'КЛЕВЕРЛИ'],
#  ['ТРАМП', 'КЭРОЛЛ'],
#  ['ЛУКАШЕНКО', 'Путин', 'ХРЕНИН'],
#  ['Столтенберг', 'Орбан'],
#  ['Путин', 'Лукашенко'],
#  ['Никитин', 'ПРИЛЕПИН'],
#  ['ЛИРА', 'ДИВАЙН'],
#  ['Путин',
#   'БЕРДЫМУХАМЕДОВ',
#   'ЖАПАРОВ',
#   'ТОКАЕВ',
#   'ПАШИНЯН',
#   'Рахмон',
#   'МИРЗИЕЕВ',
#   'Лукашенко'],
#  ['КУРКОВИЧ', 'БОГОМАЗ'],
#  ['ЖАПАРОВ', 'ТОКАЕВ', 'ПАШИНЯН', 'Рахмон', 'МИРЗИЕЕВ'],
#  ['Путин', 'КУРЕНКОВ'],
#  ['ПАШИНЯН', 'Путин'],
#  ['БУДАНОВ', 'Песков'],
#  ['ПЕРМЯКОВ', 'ПРИЛЕПИН'],
#  ['Кадыров', 'ПРИГОЖИН'],
#  ['Путин', 'Песков', 'ЗЕЛЕНСКИЙ'],
#  ['ТЮТРЮМОВ', 'БАРИНОВ', 'МОРГАН'],
#  ['ЧВК', 'ПРИГОЖИН'],
#  ['БАФФЕТ', 'МАНГЕР'],
#  ['Силуанов', 'Аксаков'],
#  ['ПЕРМЯКОВ', 'ПРИЛЕПИН'],
#  ['ПРИЛЕПИН', 'ВОЛК'],
#  ['Миронов', 'ПРИЛЕПИН'],
#  ['Никитин', 'ПРИЛЕПИН'],
#  ['ЮДАШКИН', 'Песков', 'ПУГАЧЕВА', 'БАБКИНА', 'ГАЗМАНОВ'],
#  ['ПЕВЧИХ',
#   'АЛБУРОВ',
#   'ОСОВЦОВ',
#   'МАКСАКОВА-ИГЕНСБЕРГС',
#   'ВОРОНЕНКОВ',
#   'ПАСТУХОВ',
#   'БРАУДЕР',
#   'МАГНИТСКИЙ'],
#  ['ПЕВЧИХ', 'АЛБУРОВ'],
#  ['Путин', 'НЕРУКОТВОРНЫЙ'],
#  ['ТРУХАНОВ', 'ТАНЦЮРА'],
#  ['БЕРКОВИЧ',
#   'СИЛАНТЬЕВ',
#   'ЛУНГИН',
#   'РАЙКИН',
#   'ФЕДЕРМЕССЕР',
#   'МЕНЬШИКОВ',
#   'СМЕХОВ',
#   'ПОЛОНСКИЙ'],
#  ['ХЛЕБОРОДОВ', 'СВИРИДОВА'],
#  ['Шойгу', 'КУЗЬМЕНКОВ'],
#  ['Булаткин', 'КОРДУПЕЛЬ'],
#  ['ПУГАЧЕВА', 'ЮДАШКИН', 'Вайкуле'],
#  ['ПАВЕЛ', 'ЗЕЛЕНСКИЙ'],
#  ['Рахмон', 'ШАРИФЗОД'],
#  ['ШАНЕЛЬ', 'ЗАХАРОВА'],
#  ['Путин', 'Рахмон'],
#  ['Клинтон', 'Путин', 'Ельцин', 'Кучма', 'МЕЙДЖОР'],
#  ['Герасимов', 'Шойгу', 'Путин', 'ПРИГОЖИН'],
#  ['ЗЕЛЕНСКИЙ', 'БОРРЕЛЬ', 'БОРРЕЛЬ'],
#  ['Песков', 'ПРИГОЖИН'],
#  ['Чемезов', 'Мишустин'],
#  ['МИЛЛИ', 'БРАУН-МЛАДШИЙ', 'Байден'],
#  ['Виндзор', 'КАМБЕРБАТЧ'],
#  ['ГАШИЧ', 'МУЖЧИН'],
#  ['Кадыров', 'Путин'],
#  ['СКАБЕЕВА', 'ТИМОФЕЕВА'],
#  ['Путин', 'Мадуро'],
#  ['БЕРКОВИЧ', 'ПЕТРИЙЧУК', 'ЯСНЫЙ'],
#  ['АЛЕКСАНДЕР', 'Рутте', 'ЗЕЛЕНСКИЙ'],
#  ['Кувайшев', 'Путин'],
#  ['ПОДОЛЯК', 'ЗЕЛЕНСКИЙ', 'Путин'],
#  ['Хинштейн', 'САВЕЛЬЕВ', 'Нерадько'],
#  ['БЕРКОВИЧ', 'ЭФРОС', 'ПЕТРИЙЧУК'],
#  ['Песков', 'Путин'],
#  ['ЖАПАРОВ', 'СУЛТАНБАЕВ'],
#  ['Обама', 'Обама'],
#  ['БЛИНОВСКАЯ', 'МИТРОШИНА', 'ЧЕКАЛИНА', 'САМОЙЛОВА'],
#  ['Байден', 'ГАРЛАНД', 'РЭЙ', 'КОМЕР'],
#  ['ВИЛЬНЕВ', 'ШАЛАМ'],
#  ['Медведев', 'ЗЕЛЕНСКИЙ'],
#  ['ЗЕЛЕНСКИЙ', 'Путин'],
#  ['АРТАМОНОВ', 'ВЕЛИКАЯ'],
#  ['ВОРОНКОВ', 'МОНТАЛВО', 'ЗАЙЦЕВА'],
#  ['ПУГАЧЕВА', 'ЧУПРАКОВА', 'ЮДАШКИН'],
#  ['Байден', 'Монди'],
#  ['Путин', 'Песков'],
#  ['ВОЛОКОЛАМСКИЙ', 'МАТЕРИ', 'КИРИЛЛ'],
#  ['ЗЕЛЕНСКИЙ', 'НИИНИСТ', 'КРИСТЕРССОН', 'ГАР', 'МЕТТ', 'ЯКОБСДОТТИР'],
#  ['ПРОТАСЕВИЧ', 'САПЕГА'],
#  ['ЧУБКО', 'МОСТЫКО', 'БЕРЕЗАНСКАЯ'],
#  ['Кавусоглу', 'ГУТЕРРИШ'],
#  ['МАШОВЕЦ', 'Аксенов', 'КОНСТАНТИНОВ', 'ПАВЛЕНКО'],
#  ['СОБОЛЕВСКИЙ', 'Медведев'],
#  ['ЧУБКО', 'МОСТЫКО'],
#  ['Путин', 'ГУСЕВ'],
#  ['ДУГИНА', 'СУЧКОВ', 'КУЗНЕЦОВ'],
#  ['ЮДАШКИН', 'ЗАЙЦЕВ'],
#  ['ЗЕЛИНСКИЙ', 'ТАНЦЮРА', 'ПРИГОЖИН'],
#  ['ЮДАШКИН', 'ЗАЙЦЕВ'],
#  ['Песков', 'ЮДАШКИН', 'ШОЛЬЦ'],
#  ['КОТЕГОВА', 'ЮДАШКИН'],
#  ['ЮДАШКИН', 'ЗАЙЦЕВ', 'ВАСИЛЬЕВ'],
#  ['ЛИСОВЕЦ', 'ЮДАШКИН', 'ЗАЙЦЕВ', 'ЛИСОВЕЦ'],
#  ['КРИШНА', 'КРИШНА'],
#  ['Медведев', 'ЗЕЛЕНСКИЙ', 'БАНДЕРА', 'Гитлер', 'МУССОЛИНИ'],
#  ['КУРКОВИЧ', 'БОГОМАЗ'],
#  ['Медведев', 'ТРАМП'],
#  ['ЗАЙЦЕВ', 'ПУГАЧЕВА', 'ПЬЕХА', 'КИРКОРОВ'],
#  ['СИЙЯРТО', 'ЗЕЛЕНСКИЙ'],
#  ['ЗЕЛЕНСКИЙ', 'МАКРОН'],
#  ['НЕПОМНЯЩИЙ', 'ЛИЖЭНЮ', 'ЛИЖЭНЯ'],
#  ['КУЗЬМЕНКОВ', 'МИЗИНЦЕВ', 'ЗОЛОТОВ'],
#  ['НЕПОМНЯЩИЙ', 'ЛИЖЭНЙ'],
#  ['ГУМЕНЮК', 'РАЗВОЖАЕВ'],
#  ['КОТАК', 'КОТАК'],
#  ['Байден', 'ГЕРШКОВИЧ'],
#  ['МАНЕВИЧ', 'БАРСУКОВ'],
#  ['НЕПОМНЯЩИЙ', 'ЛИЖЭНЕМ'],
#  ['Медведев', 'ЗЕЛЕНСКИЙ'],
#  ['Песков', 'Путин', 'Эрдоган'],
#  ['ДАВАНКОВ', 'ЧУЙЧЕНКО'],
#  ['КУРАЕВ', 'ХРИСТОС'],
#  ['РЕЗНИКОВ', 'ЗЕЛЕНСКИЙ'],
#  ['Набиулина', 'МОИСЕЕВ'],
#  ['РЕЗНИКОВ', 'Аксенов'],
#  ['ГАМОВА', 'ИСИНБАЕВА', 'БРУСНИКИНА'],
#  ['НАУСЕД', 'ШОЛЬЦ'],
#  ['СИНЕЛЬНИКОВ-МУРЫЛЕВ', 'Улюкаев', 'МАУ', 'Абызов'],
#  ['Байден', 'РЕЙГАН'],
#  ['МЕДЕВЕДЕВ', 'РЕЧАН', 'Путин', 'Медведев'],
#  ['Набиулина', 'КАРПУНИН'],
#  ['ВУЧИЧ', 'ДАНИЛО'],
#  ['Трамп', 'Клинтон', 'БАЙДЕН'],
#  ['МИРЗИЕЕВ', "О'САЛЛИВАН"],
#  ['ПАПАРЕЛЬЯ', 'РАВЕЛЬ'],
#  ['МИЗИНЦЕВ', 'СЛАДКОВ', 'Песков'],
#  ['Путин', 'ГУРЬЕВ'],
#  ['Путин', 'Эрдоган', 'ЛИХАЧЕВ', 'ДОНМЕЗ'],
#  ['Эрдоган', 'Путин'],
#  ['НЕПОМНЯЩИЙ', 'ЛИЖЭНЕМ', 'КАРЛСЕН'],
#  ['МИТРОШИНА', 'ЧЕКАЛИНА'],
#  ['ИНАСИУ', 'ШОЛЬЦ'],
#  ['ДВОРКОВИЧ', 'АЛЕКСЕЕВА'],
#  ['КОМИ', 'УЙБА'],
#  ['ПОДОЛЯК', 'КАВОЛИ'],
#  ['Кылычдароглу', 'Карлов'],
#  ['Байден', 'СОК'],
#  ['НАВАЛЬНЫЙ', 'ЧАНЫШЕВА'],
#  ['НЕПОМНЯЩИЙ', 'ЛИЖЭНЕМ'],
#  ['НИКОНОВ', 'КОЖЕВНИКОВ'],
#  ['ЗЕЛЕНСКИЙ', 'Си'],
#  ['ЗЕЛЕНСКИЙ', 'НИКИФОРОВ'],
#  ['Си', 'ЗЕЛЕНСКИЙ', 'КИРБИ'],
#  ['КИРИЛЛ', 'ЛИПАВСКИ'],
#  ['Вальцман', 'ЗЕЛЕНСКИЙ', 'АРЕСТОВИЧ'],
#  ['ЭРДОГАН', 'Кылычдароглу'],
#  ['ЗЕЛЕНСКИЙ', 'РЯБИКИН', 'КАМЫШЕВ'],
#  ['ТАРАСОВА', 'ЧЕРНЫШЕНКО'],
#  ['ЗЕЛЕНСКИЙ', 'Си'],
#  ['Си', 'ЗЕЛЕНСКИЙ', 'ПОДОЛЯК'],
#  ['Путин', 'ПАШИНЯН'],
#  ['Анальный', 'РОШЕ'],
#  ['ШАПША', 'ИВАНОВ'],
#  ['Лавров', 'БАЙДЕН', 'Путин'],
#  ['ИВАНОВ', 'КОНОВАЛОВ'],
#  ['Лавров', 'ГУТТЕРИШ', 'Путин'],
#  ['ЦЫГАНЕНКО', 'ДУГИНА', 'Дугин', 'ВОВК'],
#  ['БУДЕННЫЙ', 'МЯГКОВ'],
#  ['Медведев', 'Байден', 'Захарова'],
#  ['ГОНЧАРОВА', 'САМУСЕВ', 'ДИГМАР', 'САМУСЕВ'],
#  ['МАНИЛОВА', 'ГУСЕВ'],
#  ['Путин', 'АРТЮХОВ'],
#  ['ВАТСОН', 'Холмс', 'БОГАЧЕВ'],
#  ['Мантуров', 'Дерипаска'],
#  ['ТОРРЕМБИНЯ', 'ТОРРЕМБИНИ'],
#  ['СЕРВИС', 'КОТОВ'],
#  ['СЕРВИС', 'КОТОВ'],
#  ['ВЕДЕЛЬ', 'КЛОКОВ'],
#  ['СЕРВИС', 'КОТОВ', 'ОСКОЛКОВ'],
#  ['ГУТТЕРИШ', 'Лавров', 'Путин'],
#  ['ПРОНИН', 'ВЕРЕВКО'],
#  ['Песков', 'ЖАПАРОВ', 'Путин'],
#  ['ТАКЕР', 'Байден', 'ХАНТЕР'],
#  ['Песков', 'Путин'],
#  ['Байден', 'Ахмадзай'],
#  ['ГЛАДКОВ', 'МУХИН'],
#  ['Масимов', 'НАЗАРБАЕВ'],
#  ['Силуанов', 'КУЗНЕЦОВ'],
#  ['ТУРЧАК', 'Путин'],
#  ['Турчак', 'Путин'],
#  ['Турчак', 'Путин'],
#  ['ПЕТРОВ', 'МОЦАРТ'],
#  ['МУХИН', 'ГЛАДКОВ'],
#  ['ЖАПАРОВ', 'Песков', 'Лукашенко', 'ОВЕРЧУК'],
#  ['Лавров', 'Захарова'],
#  ['ТРАМП', 'БАЙДЕН'],
#  ['НЕПОМНЯЩИЙ', 'ЛИЖЭНЕМ'],
#  ['Маске', 'КИНГ', 'ФЕДОРОВ'],
#  ['БОРЦОВ', 'АРТАМОНОВ'],
#  ['ФИЛЕВ', 'СКУРАТОВ'],
#  ['Песков', 'ПЕСКОВ', 'ПРИГОЖИН'],
#  ['Песков', 'ПРИГОЖИН', 'СИМОНОВ'],
#  ['ГРОЗЕВ', 'СЕВЕЦ-ЕРМОЛИНА', 'ВИХАРЕВ'],
#  ['ПЕРЕСИЛЬД', 'ШИПЕНКО', 'НОВИЦКИЙ', 'ШКАПЛЕРОВ', 'ДУБРОВ', 'МОСКВИТИН'],
#  ['ЧИКУНОВ', 'СКУНМАКЕР', 'КОЛЕСНИКОВ'],
#  ['Орбан', 'Столтенберг'],
#  ['Медведев', 'КАРА-МУРЗА'],
#  ['КАРА-МУРЗА', 'ЛЕНСКАЯ', 'ЗАДАЧИН', 'КОЛЕСНИКОВ', 'САМОФАЛ', 'КУДРЯВЦЕВ'],
#  ['ЛИИНА', 'ВОРОБЬЕВ', 'НАХИМОВ'],
#  ['РААБ', 'СУНАК'],
#  ['Чикконе', 'РАТНИКОВ', 'ФИНКЕЛЬШТЕЙН', 'ШУРЫГИН'],
#  ['ФИРСОВ', 'ГУБКИН', 'ВАТУТИН'],
#  ['Путин', 'УСС', 'КОТЮКОВ'],
#  ['ТАВРИН', 'КРЮКОВ', 'ХАРИТОНИН', 'БАЖЕЛЬ-ТРА'],
#  ['КОЗЛОВСКИЙ', 'БОРОДИН'],
#  ['Путин', 'КОТЮКОВ'],
#  ['Путин', 'КОТЮКОВ', 'УСС'],
#  ['Маске', 'Рогозин'],
#  ['НЕПОМНЯЩИЙ', 'ЛИЖЭНЕМ'],
#  ['УСС', 'Путин'],
#  ['УСС', 'КОТЮКОВ'],
#  ['БАНН', 'Обама'],
#  ['БЕЛЬСКИЙ', 'ВИШНЕВСКИЙ', 'ШИШЛОВ'],
#  ['АВАКЯНЦ', 'Трутнев'],
#  ['Ф', 'КЕННЕДИ', 'Ф'],
#  ['МАЛЯР', 'Песков'],
#  ['Путин', 'Голикова'],
#  ['СЕРЕБРЕННИКОВ', 'УРИН', 'НУРЕЕВ'],
#  ['Шойгу', 'Каракаев'],
#  ['КОЗЛОВСКИЙ', 'БОРОДИН'],
#  ['БАЛАБКИНА', 'ТУМУСОВ'],
#  ['ЕВДОКИМОВ', 'ТАРАБАН'],
#  ['Медведев', 'СОК'],
#  ['РЕЧАН', 'Менниханов'],
#  ['СУШКЕВИЧ', 'БЕЛА', 'ВЬЮНОВ'],
#  ['ШУЛЬЕВ', 'БУТУСОВ', 'ЦВЕЙГ'],
#  ['ШИРШИКОВ', 'ГЕРШКОВИЧ', 'КАРИМОВА'],
#  ['С', 'К'],
#  ['ПЕСКОВ', 'ШОЙГУ', 'ГЕРАСИМОВ', 'Путин'],
#  ['ПАШИНЯН', 'ОЛСОН'],
#  ['Песков', 'Путин'],
#  ['Лукашенко', 'ПУШИЛИН'],
#  ['Лукашенко', 'ПУШИЛИН'],
#  ['ЛАПИН', 'Путин'],
#  ['Путин', 'ТЕПЛИНСКИЙ'],
#  ['Путин', 'МАКАРЕВИЧ', 'ТЕПЛИНСКИЙ'],
#  ['Володин', 'Путин', 'ЛЬВОВОЙ-БЕЛОВА'],
#  ['ЧАЛИК', 'РЕШЕТНИКОВ'],
#  ['ЕВТУШЕНКОВ', 'ЕВТУШЕНКОВ'],
#  ['САВЧЕНКО', 'ВАССЕРМАН', 'Аксаков'],
#  ['КАРА-МУРЗА', 'ПОТЕЕВ'],
#  ['Григорьев', 'Лавров'],
#  ['ТРЕЙСИ', 'Володин', 'Нуланд'],
#  ['КАРА-МУРЗА', 'РИНКЕВИЧС'],
#  ['Путин', 'ШОЙГУ'],
#  ['ШОЙГУ', 'Путин'],
#  ['БРАЙТМАН', 'ДАЭ', 'УЭББЕР'],
#  ['Путин', 'Шойгу'],
#  ['Путин', 'Песков'],
#  ['СУНАК', 'СТАРМЕР'],
#  ['Мишустин', 'Силуанов'],
#  ['ЗЕЛЕНСКИЙ', 'АКИНФЕЕВ', 'ТУКТАМЫШЕВА', 'ГАЗИНСКИЙ', 'ШОЙГУ'],
#  ['КРЫЛОВ', 'ГОЛДИН', 'РУСЕЦКИЙ'],
#  ['ФЕКЛИСТОВ', 'ВОЛОШИНА'],
#  ['Маске', 'БАБУШКИН'],
#  ['КАНЫГИН', 'МУНТЯН', 'ЯКОВЕНКО', 'КАРНЕГИ'],
#  ['Маске', 'ДЕСАНТИС', 'Трамп'],
#  ['КОЗЛОВСКИЙ', 'БОРОДИН', 'ШИХМАН'],
#  ['ХЭТФИЛД', 'УЛЬРИХ', 'ТРУХИЛЬО'],
#  ['Медведев', 'МОРАВЕЦКИЙ'],
#  ['Орбакайте', 'ПУГАЧЕВА'],
#  ['ЛОМОНОСОВ', 'ФЕДОРОВА'],
#  ['ЛИ', 'Шойгу', 'КЕФЯ'],
#  ['АДВОКАТ', 'ГАШИНСКИЙ'],
#  ['Орбан', 'Байден'],
#  ['БОГОМОЛОВ', 'БОГОМОЛОВ'],
#  ['РУБИНЯ', 'РУБИНИ'],
#  ['Медведев', 'Маске', 'ОСИПОВ'],
#  ['Лавров', 'Антонов'],
#  ['ЗЕЛЕНСКИЙ', 'АРТЮХ', 'ЛЫСОГОР'],
#  ['УСС', 'НОРДИО'],
#  ['КОСЫХ', 'ДЖЕЛАНТИК'],
#  ['ЗЕЛЕНСКАЯ', 'ГЕРШКОВИЧ', 'ГРАЙНЕР', 'Бут'],
#  ['Хинштейн', 'Путин'],
#  ['МОСКАЛЕВ', 'ЕФРЕМОВ'],
#  ['ДЕМЧЕНКО', 'ОГАНЕСЯН'],
#  ['ФОМИН', 'ТАТАРСКИЙ', 'ТРЕПОВА', 'ДЕНИСОВ', 'БЕРМАН', 'НАВАЛЬНЫЙ'],
#  ['ТАТАРСКИЙ', 'ДЕНИСОВ', 'ТРЕПОВА'],
#  ['Лавров', 'Антонов'],
#  ['Немцов', 'ГАЙДАР', 'ХАКАМАДА', 'Крашенинников'],
#  ['ТРАМП', 'БОЛТОН', 'РЕЙГАН'],
#  ['МИЛЛИАРДЕР', 'ГЕЙТС'],
#  ['Усманов', 'Патаркацишвили'],
#  ['КРАСНОВ', 'Маске', 'Медведев'],
#  ['БАГИРОВ', 'Симонян'],
#  ['Усманов', 'ЭФЕНДИЕВ', 'УГАРОВ'],
#  ['Путин', 'ЗЕЛЕНСКИЙ'],
#  ['Борисов', 'Путин', 'Рогозин'],
#  ['НАРУСОВА', 'ТИМЧЕНКО'],
#  ['МОГУЧИЙ', 'АРХИПОВА'],
#  ['Усманов', 'ЕВТУШЕНКОВ', 'КЕРИМОВ'],
#  ['Набиулина', 'НАБИУЛЛИН'],
#  ['РАЗВОЖАЕВ', 'Аксенов'],
#  ['Трамп', 'Си', 'Путин', 'Ким'],
#  ['Титов', 'Костин'],
#  ['МЕДВЕДЧУК', 'МАРЧЕНКО'],
#  ['Дуров', 'ХОПФ'],
#  ['Менниханов', 'Панков', 'ИСАЙКИН'],
#  ['Песков', 'Костин'],
#  ['эль-Сиси', 'АД-ДИН'],
#  ['РАТНЕР', 'ЛУЧШЕВ', 'АКАТАЕВ'],
#  ['КРЕНШОУ', 'ВАЛЬЦ'],
#  ['ДЖАПАРОВА', 'Монди'],
#  ['СКВОРЦОВ', 'АРИСТОВ'],
#  ['Трамп', 'ДЕСАНТИС'],
#  ['Нетаниягу', 'ГАЛАНТ'],
#  ['ЗЕЛЕНСКИЙ', 'КРАВЧЕНКО', 'КУЛЕБА'],
#  ['ТОКАЕВ', 'Алиев'],
#  ['ЛУКАШЕНКО', 'Шойгу', 'Путин'],
#  ['ГОРЕЛКИН', 'Маске'],
#  ['АРБЕНИНА', 'СУХАРЕВ'],
#  ['СТАРОВОЙТ', 'ГЛАДКОВ'],
#  ['Маске', 'Медведев'],
#  ['Си', 'МАКРОН'],
#  ['УСС', 'УСС', 'Путин'],
#  ['ШУЛЬМАН', 'ДЖЕЙН', 'УИВЕР', 'БЕЛЛУЧЧИ', 'Хайек'],
#  ['ЗЕЛЕНСКИЙ', 'ВЕЛИКИЙ'],
#  ['УСТЕНКО', 'ЗЕЛЕНСКИЙ'],
#  ['ТРЕПОВА', 'ТАТАРСКИЙ'],
#  ['ГЕРШКОВИЧ', 'УИЛИН'],
#  ['МАКРОН', 'Песков', 'Си'],
#  ['Саралиев', 'ЗАРИВНАЯ'],
#  ['ЭБЕЛЬ', 'РЭЙ', 'ТАТАРСКИЙ'],
#  ['ВОЛЬФ', 'Путин'],
#  ['Форд', 'МАНГОЛЬД'],
#  ['МАГОМЕДОВ', 'МАГОМЕДОВ'],
#  ['ПОДОЛЯК', 'Песков'],
#  ['ЗВЯГИНЦЕВ', 'ФИНЧЕР'],
#  ['Песков', 'МАКРОН'],
#  ['Берлускони', 'МИНЦОЛИНИ'],
#  ['БЛИНКЕН', 'ЗЕЛЕНСКИЙ'],
#  ['АДАНЯ', 'МАЛИК'],
#  ['ЕМЕЛЬЯНЕНКО', 'БУРЧАК'],
#  ['СТОРМИ', 'Трамп'],
#  ['ДАНИЛОВ', 'ЗЕЛЕНСКИЙ'],
#  ['ВАСИЛЕНКОВ', 'ВАСИЛЕНКОВ'],
#  ['Лукашенко', 'Бортников', 'Путин'],
#  ['ВОВК', 'ТАРАСОВ'],
#  ['Силуанов', 'ЗАРУБИН'],
#  ['Лукашенко', 'МАКРОН'],
#  ['Клишас', 'Морозов', 'ЗОРЬКИН'],
#  ['Путин', 'ПУШИЛИН'],
#  ['БАЛАГОВ', 'СОКУРОВ'],
#  ['Путин',
#   'ГАСПАРЯН',
#   'Лукьяненко',
#   'ЛУНДСТРЕМ',
#   'МАЛЬКЕВИЧ',
#   'СОДНОМДОРЖИЕВ',
#   'БОКЕРИЯ',
#   'Винер-Усманова',
#   'ГУРЦКАЯ',
#   'КАРЯКИН',
#   'ЛЕГОЙДА'],
#  ['Путин', 'Лукашенко'],
#  ['Си', 'Песков'],
#  ['ХАУТИЕВ', 'АЛЕХИН', 'РОДИОНОВ'],
#  ['МАКРОН', 'Си'],
#  ['САНН', 'МАРИН', 'НИИНИСТ'],
#  ['ДЕГТЯРЕВ', 'СЕЛИВАНОВ'],
#  ['КЕННЕДИ', 'Ф', 'Ф', 'УИЛЬЯМСОН', 'Байден'],
#  ['Путин', 'ЛУКАШЕНКО'],
#  ['АПРАКСИН', 'ЖУКОВ'],
#  ['Дерипаска', 'Полонский', 'МЕЛЬНИКОВ', 'МИНСКЕР', 'КАЗАКОВ'],
#  ['Собянин', 'Гайнутдинов'],
#  ['ТРАМП-МЛАДШИЙ', 'ДОСТОЕВСКИЙ'],
#  ['ДОЛГОПОЛОВ', 'ОГАНИСЯН', 'ФОМИН', 'ТАТАРСКИЙ', 'ТРЕПОВА'],
#  ['КОРОЛЕВ', 'БЕРДНИКОВ'],
#  ['ЗЕЛЕНСКИЙ', 'Дуда'],
#  ['Путин', 'ГРЕЧУШКИН', 'ЧУПРИЯН'],
#  ['Песков', 'Путин', 'Си'],
#  ['Путин', 'Си'],
#  ['ДЖЕЙМИСОН', 'ШАНД'],
#  ['ОБАМА', 'Райс', 'РЭЙ'],
#  ['КОШЕЛЕВ', 'ВЫРОПАЕВ'],
#  ['МАКРОН', 'Си'],
#  ['ЗЕЛЕНСКИЙ', 'Дуда'],
#  ['Клинтон', 'Ельцин', 'КРАВЧУК', 'СОКОЛОВ'],
#  ['Трамп', 'БРЭГГ'],
#  ['ТРАМП', 'ДЭНИЭЛС'],
#  ['ТРАМП', 'ДЭНИЭЛС', 'СТОРМИ', 'КЛИФФОРД', 'КОЭН'],
#  ['ТРАМП', 'КОЭН'],
#  ['Маске', 'Трамп'],
#  ['ТРАМП', 'Байден', 'ЖАН-ПЬЕР'],
#  ['Трамп', 'ЖАН-ПЬЕР'],
#  ['Трамп', 'УЛИСС'],
#  ['АЛЕШКОВИЧ', 'БОГОМАЗ'],
#  ['ТРЕПОВА', 'ЛЮБИМОВ'],
#  ['МИЧКОВ', 'МИЧКОВ'],
#  ['ТРЕПОВА', 'ТАТАРСКИЙ'],
#  ['Потанин',
#   'ЛИСИН',
#   'МИХЕЛЬСОН',
#   'МОРДАШОВ',
#   'ШТЕНГЕЛОВ',
#   'КРИВЕНКО',
#   'Дуров',
#   'БАКАЛЬЧУК',
#   'БУХМАНОВ',
#   'БУХМАНОВ'],
#  ['АРНО', 'Маске', 'БЕЗОС'],
#  ['МЕЛЬНИЧЕНКО', 'ЛИСИН'],
#  ['ТРАМП', 'ПОМПЕО'],
#  ['СОРОС', 'Сорос'],
#  ['Роулинг', 'ПОТТЕР'],
#  ['ЕЛИСЕЕВ', 'ГРЕК'],
#  ['ПРЕДТЕЧЕНСКИЙ', 'КОРОПАЧИНСКИЙ', 'КИРИЛЛОВ', 'ЗЕЛЬВЕНСКИЙ', 'Мамут'],
#  ['ТАТАРСКИЙ', 'АРНИС', 'ТРЕПОВА'],
#  ['Клишас', 'Володин'],
#  ['ТРАМП', 'КИРБИ', 'ДЭНИЭЛС', 'КОЭН'],
#  ['ЦЗЭДУН', 'Си', 'Путин'],
#  ['САПЕГА', 'ПРОТАСЕВИЧ', 'Лукашенко'],
#  ['БРЭНСОН', 'ХАРТ'],
#  ['ТРЕПОВА', 'ТАТАРСКИЙ'],
#  ['ТАТАРСКИЙ', 'ДУГИНА', 'Путин'],
#  ['Медведев', 'ТРЕПОВА'],
#  ['ТРЕПОВА', 'ТАТАРСКИЙ'],
#  ['САНН', 'ДЖУКАНОВИЧ'],
#  ['МЕДВЕДЕВ', 'СИННЕР'],
#  ['ТАТАРСКИЙ', 'БЕГЛОВ', 'ФОМИН', 'ПЕЛЕВИН', 'Пучков'],
#  ['ЗЕЛЕНСКИЙ', 'ТАТАРСКИЙ', 'ПОДОЛЯК'],
#  ['БУТОРИНА', 'ТАТАРСКИЙ', 'ФРОНТ'],
#  ['МАМОНОВ', 'ТАТАРСКИЙ', 'СТАТУЭТК'],
#  ['ТАТАРСКИЙ', 'ФРОНТ'],
#  ['СТАРОВОЙТ', 'ГЛАДКОВ'],
#  ['БЛИНКЕН', 'Лавров', 'ГЕРШКОВИЧ'],
#  ['Шойгу', 'Каракаев'],
#  ['БОРРЕЛЬ', 'Медведев'],
#  ['КОЗЛОВСКИЙ', 'БОРОДИН'],
#  ['БАЛАБКИНА', 'ТУМУСОВ'],
#  ['ЕВДОКИМОВ', 'ТАРАБАН'],
#  ['ДАНИЛОВ', 'РАЗВОЖАЕВ'],
#  ['Медведев', 'СОК'],
#  ['ГАГИН', 'СКАБЕЕВА'],
#  ['РЕЧАН', 'Менниханов'],
#  ['АБРАМЧЕНКО', 'Меняйло', 'КВАСОВ'],
#  ['МЕДВЕДЕВ', 'ХАЧАНОВ'],
#  ['ЧЕНТЕМИРОВ', 'БОЙКО', 'АКУНИН', 'БАРЫШНИКОВ', 'Гуриев'],
#  ['Клишас', 'ШВЫДКИН', 'ЗАВАРЗИН'],
#  ['КАЛВИ', 'ИВАШЕНЦЕВА'],
#  ['ГЕРШКОВИЧ', 'Байден'],
#  ['КОРЕНЕВСКИЙ', 'СТАРОВОЙТ'],
#  ['Песков', 'Путин', 'ЛУКАШЕНКО'],
#  ['МЕЛЬНИКОВ', 'ЕМЕЛЬЯНОВА', 'Булгаков', 'ПИЛАТ'],
#  ['ЗАЙЦЕВ', 'СТАРОВОЙТ'],
#  ['ЧАНСЛИ', 'Трамп', 'ЧАНСЛИ'],
#  ['Трамп', 'ДЭНИЭЛС'],
#  ['Шойгу', 'Каракаев'],
#  ['ТЕРЕХОВ', 'СИНЕГУБОВ'],
#  ['КОЗЛОВСКИЙ', 'БОРОДИН'],
#  ['БАЛАБКИНА', 'ТУМУСОВ'],
#  ['ЕВДОКИМОВ', 'ТАРАБАН'],
#  ['Байден', 'ГЕРШКОВИЧ', 'Захарова'],
#  ['Медведев', 'СОК'],
#  ['ГЕРШКОВИЧ', 'БЛИНКЕН'],
#  ['РЕЧАН', 'Менниханов'],
#  ['ЕГОРОВА', 'КУЛЕШОВА'],
#  ['МОСКАЛЕВ', 'МОСКАЛЕВА', 'Песков'],
#  ['ГЕРШКОВИЧ', 'БЕРМАН'],
#  ['УОЛЛЕС', 'ЙОНСОН'],
#  ['ГАГИН', 'СКАБЕЕВА'],
#  ['Песков', 'Бортников'],
#  ['Кадыров', 'ЧУВИЛИН', 'ЗАХАРЧЕНКО'],
#  ['МОРИ', 'ХЕНМИ'],
#  ['ГЕРШКОВИЧ', 'ШИРШИКОВ'],
#  ['Маске', 'ВОЗНЯК', 'КАЕМ', 'НИКОЛАЕВ', 'ЕРМИЛОВ'],
#  ['СУШКЕВИЧ', 'БЕЛА', 'ВЬЮНОВ'],
#  ['Путин', 'Кириенко'],
#  ['СЕМЕНОВ', 'ГОРОВАЯ', 'СМИРНОВ'],
#  ['ШУЛЬЕВ', 'БУТУСОВ', 'ЦВЕЙГ'],
#  ['Путин', 'Эрдоган'],
#  ['Путин', 'МАКРОН', 'ШОЛЬЦ', 'Песков'],
#  ['ШИРШИКОВ', 'ГЕРШКОВИЧ', 'КАРИМОВА'],
#  ['ЛУШНИКОВ', 'ГОРЕМЫКИН', 'ХАРИЧЕВ', 'РАПОПОРТ'],
#  ['Путин', 'ЧУПРИЯН', 'ЗИНИЧЕВ', 'КУРЕНКОВ'],
#  ['С', 'К'],
#  ['РЕЗНИКОВ', 'ПУШИЛИН'],
#  ['ПЕСКОВ', 'ШОЙГУ', 'ГЕРАСИМОВ', 'Путин'],
#  ['Байден', 'Дерипаска'],
#  ['Путин', 'ХОЦЕНКО', 'БУРКОВ'],
#  ['СИМОНЕНКО', 'ЕГОРОВА', 'КУЛЕШОВА'],
#  ['ПАШИНЯН', 'ОЛСОН'],
#  ['ГЛАДКОВ', 'ДЕМИДОВ'],
#  ['Песков', 'Путин'],
#  ['Лукашенко', 'ПУШИЛИН'],
#  ['КОВАЧ', 'КРИСТЕРССОН', 'Орбан'],
#  ['Лукашенко', 'ПУШИЛИН'],
#  ['ЗЕЛЕНСКИЙ', 'Йелен'],
#  ['Песков', 'Путин'],
#  ['ГРОССИ', 'РОГОВ'],
#  ['Путин', 'ПУЧКОВ', 'ПОДОЛЯКА'],
#  ['Улюкаев', 'ПАСТЕРНАК', 'Сечин'],
#  ['ПОМПЕО', 'ЗЕЛЕНСКИЙ'],
#  ['Путин', 'СИГАЛ'],
#  ['ДРОНОВ', 'Путин'],
#  ['БАСУРИН', 'ПРИГОЖИН'],
#  ['Лукашенко', 'ЛАППО'],
#  ['ЛАПИН', 'Путин'],
#  ['Путин', 'ТЕПЛИНСКИЙ'],
#  ['Путин', 'МАКАРЕВИЧ', 'ТЕПЛИНСКИЙ'],
#  ['ТИХАНОВСКАЯ', 'ЛАТУШКО', 'КОВАЛЬКОВА', 'ДЫЛЕВСКИЙ'],
#  ['ЗЕЛЕНСКИЙ', 'Си'],
#  ['ТОКАЕВ', 'СМАИЛОВ'],
#  ['ВАШИНГТОН', 'ЧУМАКОВ'],
#  ['Москалькова', 'ЛУБИНЦ', 'ЛУБИНЕЦ'],
#  ['Володин', 'Путин', 'ЛЬВОВОЙ-БЕЛОВА'],
#  ['САФРОНОВ', 'КАТЧЕВ'],
#  ['ЧАЛИК', 'РЕШЕТНИКОВ'],
#  ['СТАРОВОЙТ', 'КОРЕНЕВСКИЙ'],
#  ['Песков', 'Путин', 'Лукашенко'],
#  ['МУСАЕВ', 'ФЕДОТОВ', 'ОЗМАН'],
#  ['ОБАЙТЕК', 'ДЕМИН'],
#  ['Нарышкин', 'БЕРНС'],
#  ['МОСКАЛЕВ', 'БИЛИЕНКО', 'МОСКАЛЕВА'],
#  ['ЦВЕТКОВА', 'ПИХОВКИН'],
#  ['САРДАРОВА', 'АСКЕРИ'],
#  ['ЕВТУШЕНКОВ', 'ЕВТУШЕНКОВ'],
#  ['ШАПОШНИКОВ', 'КОМИ', 'УЙБА'],
#  ['ФЕДУЛОВА', 'АРХАРОВА', 'УШАКОВ', 'ЧУРИЛОВА', 'БАЯЗИТОВА', 'УШАКОВ'],
#  ['САВЧЕНКО', 'ВАССЕРМАН', 'Аксаков'],
#  ['ПАВЛОВСКИЙ', 'Путин'],
#  ['КАРА-МУРЗА', 'ПОТЕЕВ'],
#  ['БОРРЕЛЬ', 'БОРРЕЛЬ'],
#  ['ШАВА', 'Лукашенко'],
#  ['Григорьев', 'Лавров'],
#  ['ПИСТОРИУС', 'Путин'],
#  ['ТРЕЙСИ', 'Володин', 'Нуланд'],
#  ['КИНДЕР', 'САВЕЛЬЕВ'],
#  ['КАРА-МУРЗА', 'РИНКЕВИЧС'],
#  ['Тимакова', 'Медведев', 'Шувалов'],
#  ['ГОРДЕЕВ', 'РОТЕНБЕРГ', 'Ротенберг', 'ПОНОМАРЕНКО', 'СКОРОБОГАТЬКО'],
#  ['Трамп', 'БОЛТОН'],
#  ['Путин', 'КОБЗЕВ'],
#  ['Маске', 'ПОДОЛЯК'],
#  ['Путин', 'ШОЙГУ'],
#  ['ШОЛЬЦ', 'ЭРНСТ'],
#  ['ШОЙГУ', 'Путин'],
#  ['БЕРНС', 'Нарышкин', 'Путин'],
#  ['ШИШХАНОВ', 'ЛУКИН'],
#  ['ЗЕЛЕНСКИЙ', 'ГРОССИ'],
#  ['Путин', 'ТОКАЕВ'],
#  ['БРАЙТМАН', 'ДАЭ', 'УЭББЕР'],
#  ['Путин', 'Шойгу'],
#  ['Путин', 'Песков'],
#  ['ИВЕНЬ', 'СЯОГУАН', 'ИНВЭНЬ', 'СЯОГУАН'],
#  ['Мантуров', 'Путин'],
#  ['КЕННАН', 'МЭННИНГ', 'ПАУЭЛЛ', 'Блэр', 'Путин', 'СТАЛИН'],
#  ['ДОБРОДЕЕВ', 'ДЖУМАЕВ'],
#  ['РЕЗНИКОВ', 'ЖУЛЯН'],
#  ['КАРЧАА', 'Кадыров'],
#  ['Медведев', 'ПЕЛОСИ'],
#  ['Байден', 'Путин', 'Си'],
#  ['БАФФЕТ', 'Сорос', 'ДАЛИО', 'БЬЮРРИ'],
#  ['ГЕРЦОГ', 'Нетаниягу'],
#  ['АЯЛОН', 'ГАЛАНТ', 'Нетаниягу'],
#  ['ШОЛЬЦ', 'БРУХ'],
#  ['КАЦЕНЕЛЬСОН', 'ЛЯКИШЕВ', 'ЕРАСТОВ'],
#  ['СУНАК', 'СТАРМЕР'],
#  ['КАБАЕВА', 'ПОПОВА', 'ИВАЩЕНКО', 'САЛЬДО', 'СТРЕМОУСОВ', 'ЕЛИСЕЕВ'],
#  ['МИРАНЧУК', 'ПИНЯЕВ'],
#  ['Трюдо',
#   'Медведев',
#   'Кириенко',
#   'Кадыров',
#   'МОРДАШОВ',
#   'НИСАНОВ',
#   'МЕЛЬНИЧЕНКО'],
#  ['Трамп', 'Маске', 'Байден', 'Обама'],
#  ['ПУМПЯНСКИЙ', 'РАШНИКОВ', 'МЕЛЬНИЧЕНКО', 'ПОНОМАРЕНКО'],
#  ['Мишустин', 'Силуанов'],
#  ['МАКРОН', 'ШОЛЬЦ', 'ЗЕЛЕНСКИЙ'],
#  ['Кук', 'КРИСТИАНО', 'БУРЛА', 'ДАЛИО'],
#  ['ЗЕЛЕНСКИЙ', 'АКИНФЕЕВ', 'ТУКТАМЫШЕВА', 'ГАЗИНСКИЙ', 'ШОЙГУ'],
#  ['Маске', 'Трамп'],
#  ['МЕССИ', 'РОНАЛДУ', 'ЛЕЙБОВИТЦ'],
#  ['ПЕЛОСИ', 'САРМАТОВ'],
#  ['Саакашвили', 'ГЕЛБАХИАНИ'],
#  ['ПАСЕЧНИК', 'ЖОГИ', 'ЖОГИ'],
#  ['ЧЕКУНКОВ',
#   'ФАЛЬКОВ',
#   'КОТЯКОВ',
#   'КОЗЛОВ',
#   'КУРЕНКОВ',
#   'ЛЮБИМОВА',
#   'МАТЫЦИН',
#   'ШАДАЕВ',
#   'ШУЛЬГИНОВ'],
#  ['БАБУШКИН',
#   'БЕЗДУДНЫЙ',
#   'БРЕЧАЛОВ',
#   'БУРКОВ',
#   'БУСАРГИН',
#   'ЧИБИС',
#   'Дегтерев',
#   'ЕВРАЕВ',
#   'КАЛИМАТОВ',
#   'ХАСИКОВ',
#   'ХОРОХОРДИН',
#   'ХОВАЛЫГ',
#   'КЛЫЧКОВ',
#   'КОБЗЕВ',
#   'КОМАРОВА',
#   'Кондратьев',
#   'КОНОВАЛОВ'],
#  ['КРЫЛОВ', 'ГОЛДИН', 'РУСЕЦКИЙ'],
#  ['ПРИГОЖИН', 'Кувайшев', 'Сталин', 'БЕГЛОВ'],
#  ['Лавров', 'Захарова'],
#  ['Медведев', 'ЗЕЛЕНСКИЙ'],
#  ['СУНАК', 'ЗЕЛЕНСКИЙ'],
#  ['ФЕКЛИСТОВ', 'ВОЛОШИНА'],
#  ['Лукашенко', 'Путин', 'ЗЕЛЕНСКИЙ'],
#  ['РЕЙГАН', 'БАШ'],
#  ['ПЕЛОСИ', 'Кадыров'],
#  ['Лавров', 'ЛУКАШЕВИЧ'],
#  ['ЗЕЛЕНСКИЙ', 'Песков', 'Лавров'],
#  ['МОРАВЕЦКИЙ', 'ШМЫГАЛЬ'],
#  ['Кувайшев', 'ПРИГОЖИН'],
#  ['Дворкович', 'Песков', 'Турчак'],
#  ['Маске', 'БАБУШКИН'],
#  ['Захарова', 'СКИБИЦКИЙ'],
#  ['Медведев', 'ЗЕЛЕНСКИЙ'],
#  ['Путин', 'Песков'],
#  ['КЛЕВЕРЛИ', 'ВАРНИГ', 'КАБАЕВА', 'КАБАЕВА', 'ДЮМИН', 'КОЗАК', 'Козак'],
#  ['Байден', 'Путин', 'Песков'],
#  ['ЗАГИТОВА', 'МЕДВЕДЕВА'],
#  ['КАНЫГИН', 'МУНТЯН', 'ЯКОВЕНКО', 'КАРНЕГИ'],
#  ['Путин', 'Песков'],
#  ['НАБИУЛЛИНА', 'Дугин'],
#  ['Лукашенко', 'Макей'],
#  ['Маске', 'ДЕСАНТИС', 'Трамп'],
#  ['Миллер', 'Путин', 'Куприянов'],
#  ['Фридман', 'Путин', 'АВЕН'],
#  ['Путин', 'Байден'],
#  ['Байден', 'ЧУНЬИН'],
#  ['КОЛЕЗЕВ', 'ШИХМАН', 'ЗАЯКИН'],
#  ['КОЗЛОВСКИЙ', 'БОРОДИН', 'ШИХМАН'],
#  ['Эрнст', 'ФОКИН'],
#  ['АЛЕКСЕЕВ',
#   'МАЛЬЦЕВ',
#   'ШИХМАН',
#   'СВЕТОВ',
#   'ЗАЯКИН',
#   'КОЛЕЗЕВ',
#   'БИККИНИН',
#   'УСАНОВ',
#   'КАРПУК',
#   'ЛЕВИЕВ'],
#  ['Дуров', 'АЛЬ-МАКТУМ'],
#  ['КОЛЕЗЕВ', 'ШИХМАН', 'СВЕТОВ', 'МАЛЬЦЕВ', 'АЛЕКСЕЕВ'],
#  ['Эрдоган', 'ЗЕЛЕНСКИЙ'],
#  ['Медведев', 'ОСИПОВ'],
#  ['ПЕЛОСИ', 'РЕЙГАН'],
#  ['ХЭТФИЛД', 'УЛЬРИХ', 'ТРУХИЛЬО'],
#  ['Ельцин', 'РОВНЕЙКО'],
#  ['КУДРЯКОВ', 'МАГНИТСКИЙ'],
#  ['ШОЛЬЦ', 'МЕЛЬНИК'],
#  ['Трамп', 'БОЛТОН', 'Байден', 'Путин'],
#  ['АЗ-ЗАВАХИРИ', 'БЛИНКЕН'],
#  ['Си', 'Лукашенко'],
#  ['Путин', 'Лавров', 'СПИРИДОНОВ'],
#  ['Медведев', 'МОРАВЕЦКИЙ'],
#  ['НЬЮСОМ', 'ХОЧУЛ'],
#  ['ЗЕЛЕНСКИЙ', 'Мединский', 'Лавров'],
#  ['Анальный', 'БОРРЕЛЬ'],
#  ['ДУДА', 'Меркель', 'Путин', 'Дуда'],
#  ['МУРАВИЦКИЙ', 'ШЕКСПИР'],
#  ['ЖАН-ПЬЕР', 'Бут', 'УИЛАН', 'ГРАЙНЕР', 'КЛЮШИН'],
#  ['ТЭВДОЙ-БУРМУЛИ', 'ЛАПИН'],
#  ['ВДОВИЧЕНКОВОВ', 'ЧЕБАТКОВ', 'РАСТЕРЯЕВ'],
#  ['Анальный', 'АРТЕМЕНКО', 'БОРРЕЛЬ'],
#  ['Собчак', 'ОЛЬШАНСКАЯ'],
#  ['Орбакайте', 'ПУГАЧЕВА'],
#  ['ЛОМОНОСОВ', 'ФЕДОРОВА'],
#  ['ЗЕЛЕНСКИЙ', 'КОЗАК', 'ДАЛЬ'],
#  ['Байден', 'Песков'],
#  ['Собчак', 'САФРОНОВ'],
#  ['Медведев', 'Обама'],
#  ['САФРОНОВ', 'ЦОРН', 'ФЕДУН'],
#  ['ПАСКИНА',
#   'ВЕРМАН',
#   'ЯНЧИШИН',
#   'ЖУЛИНСКАЯ',
#   'БАЛАНОВА',
#   'БАЛАНОВ',
#   'ЛАНИНА',
#   'Потанин'],
#  ['МОИСЕЕВ', 'Иванов', 'Тимченко', 'ИВАНОВ'],
#  ['ЯНКАУСКАС', 'УТКИН'],
#  ['ЛИ', 'Шойгу', 'КЕФЯ'],
#  ['РЯБЦЕВ', 'САФРОНОВ'],
#  ['КОЛЕСНИКОВ', 'НАВАЛЬНЫЙ'],
#  ['ВОРОНКИН', 'КАРА-ООЛ', 'Путин', 'ХОВАЛЫГ', 'Шойгу'],
#  ['КОЛЕСНИКОВ', 'НАВАЛЬНЫЙ'],
#  ['ФЕДУН', 'ХАЧАТУРЯНЦА'],
#  ['Маске', 'Нуланд'],
#  ['ВАЛУЕВА', 'КУЗЕНКОВ'],
#  ['НАВАЛЬНЫЙ', 'КОЛЕСНИКОВ', 'АРТЕМЕНКО'],
#  ['Медведев', 'БАЙДЕН'],
#  ['ЧАБАН', 'САФРОНОВ', 'КАТЧЕВ'],
#  ['ГЛУХОВСКИЙ', 'ГЛУХОВСКАЯ'],
#  ['ТИМУРОВА', 'АРТЕМЕНКО', 'ЗИНАТ', 'НАВАЛЬНЫЙ', 'ТИМУРОВ'],
#  ['АДВОКАТ', 'ГАШИНСКИЙ'],
#  ['САФРОНОВ', 'Рогозин', 'ГОЛУНОВ', 'ПРОКОПЬЕВА'],
#  ['АКИМОВ', 'НАВАЛЬНЫЙ', 'МИХАЙЛОВА', 'ЛЕБЕДЕВ'],
#  ['САЛЬДО', 'АНТОНОВСКИЙ'],
#  ['ГУБАРЕВА', 'ГУБАРЕВ'],
#  ['НАВАЛЬНЫЙ', 'АРТЕМЕНКО'],
#  ['НАРУСОВА', 'Путин', 'АХЕДЖАКОВА', 'Матвиенко'],
#  ['Ельцин', 'Зюганов', 'РУЦКОЙ', 'ХАСБУЛАТОВ', 'КОРЖАКОВ', 'ЕЛЬЦИНА'],
#  ['НАВАЛЬНЫЙ', 'МАРГУЛИС'],
#  ['Орбан', 'Байден'],
#  ['ЧЕРНЫХ', 'ЧУРАКОВА', 'ДЕРЯГИНА', 'ЧЕРНЕНКО'],
#  ['ВАСИЛЬЕВ', 'МАЛЕВИЧ', 'ЛЕПОРСКАЯ'],
#  ['Турчак', 'Дворкович'],
#  ['НАВАЛЬНЫЙ', 'АРТЕМЕНКО', 'МАРГУЛИС'],
#  ['БОГОМОЛОВ', 'БОГОМОЛОВ'],
#  ['Усманов', 'ЕРКОЖА', 'ТАРАСОВ'],
#  ['НАВАЛЬНЫЙ', 'АРТЕМЕНКО', 'ФРОЛОВА'],
#  ['РУБИНЯ', 'РУБИНИ'],
#  ['КУДРЯВЦЕВ', 'САФРОНОВ'],
#  ['КАРА-МУРЗА', 'ПРОХОРОВ'],
#  ['НАВАЛЬНЫЙ', 'АРТЕМЕНКО'],
#  ['ШМАНЕВСКИЙ', 'ГУСАК'],
#  ['САФРОНОВ', 'БЕЛЕНЬКАЯ', 'САХАРЕВИЧ', 'ГИРИН'],
#  ['Кудрин', 'ОЗЕРКОВ', 'ТОРНХИЛЛ'],
#  ['Медведев', 'Маске', 'ОСИПОВ'],
#  ['МАТЕРКОВА', 'ПРИГОВ', 'ЛОМОНОСОВ'],
#  ['НАВАЛЬНЫЙ', 'РОШЕ'],
#  ['ХАМАДА', 'КИСИД'],
#  ['НАВАЛЬНЫЙ', 'АРТЕМЕНКО'],
#  ['Путин', 'АКИМОВ'],
#  ['Берлускони', 'ЗЕЛЕНСКИЙ', 'ФРИДМАН'],
#  ['НАВАЛЬНЫЙ', 'АРТЕМЕНКО', 'ФРОЛОВА'],
#  ['ЯРОШЕНКО', 'ДРОБИЗ'],
#  ['БЕКБУЛАТОВА', 'ЧИКОВ'],
#  ...]

# %%
data_persons = []
for i in range(len(persons_pairs)):
    lst = []
    for name in persons_pairs[i]:
        lst.append(name.upper())
    data_persons.append(lst)

# %%
data_persons[:10]
# Out:
# [['ПРОНИЧЕВА', 'ШИГАПОВ', 'СЕРГИЕВА', 'ТРЕГУЛОВА', 'РАДОНЕЖСКИЙ'],
#  ['СУПЕР', 'ОРЕШКИН', 'КУЗАХМЕТОВ'],
#  ['ПРИЛЕПИН', 'НИКИТИН'],
#  ['МАСЛОВ', 'МАСЛОВА'],
#  ['МОРДАШОВ', 'МИШУСТИН'],
#  ['БЛИНКЕН', 'БАЙДЕН'],
#  ['БЕРНС', 'БАЙДЕН', 'ПЕЛОСИ', 'ХЕНЛЕ', 'БЛИНКЕН'],
#  ['ПАШИНЯН', 'ЭРДОГАН'],
#  ['КЛИМАТ', 'АФРИК'],
#  ['УОЛЛЕС', 'АКСЕНОВ']]

# %%
unique_persons = set()
for i in data_persons:
    for j in i:
        unique_persons.add(j)
        
dct = dict().fromkeys(unique_persons, [])

# %%
df = pd.DataFrame(index=list(unique_persons), columns=list(unique_persons))
df.fillna(0, inplace=True)

# %%
for row in data_persons:
    ln = len(row)
    for i in range(ln):
        for j in range(ln):
            df.at[row[i], row[j]]+=1

# %%
df
# Out:
#             ПАШАЕВ  ХАНСЕН  ТОРРЕМБИНИ  ВОЛОДИН  КОЛМАКОВ  ГЕЙТС  РЯЙККЕНЕН  \
# ПАШАЕВ         180       0           0        0         0      0          0
# ХАНСЕН           0      18           0        0         0      0          0
# ТОРРЕМБИНИ       0       0          18        0         0      0          0
# ВОЛОДИН          0       0           0      180         0      0          0
# КОЛМАКОВ         0       0           0        0        18      0          0
# ...            ...     ...         ...      ...       ...    ...        ...
# ТЮКЕЕВ           0       0           0        0         0      0          0
# МОРДВИЧЕВ        0       0           0        0         0      0          0
# ДАНИЛОВ          0       0           0        0         0      0          0
# ОСОВЦОВ          0       0           0        0         0      0          0
# СОБОЛЬ           0       0           0        0         0      0          0
#
#             МАГОМЕДОВ  ПАСКИНА  ТРЕГУЛОВА  ...  КЛЫЧКОВ  МАНИЛОВА  ЦВЕЙГ  \
# ПАШАЕВ              0        0          0  ...        0         0      0
# ХАНСЕН              0        0          0  ...        0         0      0
# ТОРРЕМБИНИ          0        0          0  ...        0         0      0
# ВОЛОДИН             0        0          0  ...        0         0      0
# КОЛМАКОВ            0        0          0  ...        0         0      0
# ...               ...      ...        ...  ...      ...       ...    ...
# ТЮКЕЕВ              0        0          0  ...        0         0      0
# МОРДВИЧЕВ           0        0          0  ...        0         0      0
# ДАНИЛОВ             0        0          0  ...        0         0      0
# ОСОВЦОВ             0        0          0  ...        0         0      0
# СОБОЛЬ              0        0          0  ...        0         0      0
#
#             ДАВОЯН  СИЗОВ  ТЮКЕЕВ  МОРДВИЧЕВ  ДАНИЛОВ  ОСОВЦОВ  СОБОЛЬ
# ПАШАЕВ           0      0       0          0        0        0       0
# ХАНСЕН           0      0       0          0        0        0       0
# ТОРРЕМБИНИ       0      0       0          0        0        0       0
# ВОЛОДИН          0      0       0          0        0        0       0
# КОЛМАКОВ         0      0       0          0        0        0       0
# ...            ...    ...     ...        ...      ...      ...     ...
# ТЮКЕЕВ           0      0      18          0        0        0       0
# МОРДВИЧЕВ        0      0       0         18        0        0       0
# ДАНИЛОВ          0      0       0          0       72        0       0
# ОСОВЦОВ          0      0       0          0        0       18       0
# СОБОЛЬ           0      0       0          0        0        0      72
#
# [1775 rows x 1775 columns]

# %%
df.to_csv('final_df.csv', index=False)
